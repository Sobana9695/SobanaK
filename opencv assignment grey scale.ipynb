# %%
import cv2
import numpy as np
import pandas as pd

# %%
import os

# %%
os.chdir(r"C:\Users\SSS\Desktop\opencv_task")  # i need to change the directory where opencv_task folder present

# %%
os.getcwd()
# Out:
# 'C:\\Users\\SSS\\Desktop\\opencv_task'

# %%
os.chdir(r"C:\Users\SSS\Desktop\opencv_task\1")
img1=[]
for i in os.listdir():
    img1.append(cv2.imread((r"C:\Users\SSS\Desktop\opencv_task\1\{}").format(i),0).flatten())
    data_one=pd.DataFrame({'array':img1,'label':1})
img1
# Out:
# [array([161, 162, 163, ...,  17,  17,  17], dtype=uint8),
#  array([161, 162, 163, ...,  17,  17,  17], dtype=uint8),
#  array([161, 162, 163, ...,  17,  17,  17], dtype=uint8),
#  array([160, 161, 161, ...,   8,   7,   7], dtype=uint8),
#  array([160, 161, 161, ...,   8,   6,   7], dtype=uint8),
#  array([160, 161, 161, ...,   8,   6,   7], dtype=uint8),
#  array([162, 160, 160, ...,  13,  14,  16], dtype=uint8),
#  array([162, 160, 160, ...,  13,  14,  16], dtype=uint8),
#  array([162, 160, 160, ...,  13,  14,  16], dtype=uint8),
#  array([162, 163, 163, ...,  15,  15,  16], dtype=uint8),
#  array([164, 164, 164, ...,  15,  15,  16], dtype=uint8),
#  array([164, 163, 161, ...,  13,  14,  15], dtype=uint8),
#  array([164, 163, 161, ...,  13,  14,  15], dtype=uint8),
#  array([164, 163, 161, ...,  13,  14,  15], dtype=uint8),
#  array([164, 163, 161, ...,  13,  14,  15], dtype=uint8),
#  array([165, 167, 168, ...,  22,  20,  19], dtype=uint8),
# ...

# %%
data_one
# Out:
#                                                  array  label
# 0    [161, 162, 163, 164, 164, 163, 161, 159, 159, ...      1
# 1    [161, 162, 163, 164, 164, 163, 161, 159, 159, ...      1
# 2    [161, 162, 163, 164, 164, 163, 161, 159, 159, ...      1
# 3    [160, 161, 161, 161, 160, 159, 159, 158, 159, ...      1
# 4    [160, 161, 161, 162, 161, 160, 159, 159, 160, ...      1
# ..                                                 ...    ...
# 151  [158, 158, 158, 158, 159, 159, 158, 156, 152, ...      1
# 152  [159, 159, 158, 158, 158, 157, 156, 155, 155, ...      1
# 153  [159, 159, 158, 158, 158, 157, 156, 155, 155, ...      1
# 154  [159, 159, 158, 158, 158, 157, 156, 155, 155, ...      1
# 155  [159, 159, 159, 158, 158, 158, 158, 158, 158, ...      1
#
# [156 rows x 2 columns]

# %%
os.chdir(r"C:\Users\SSS\Desktop\opencv_task\2")
img2=[]
for i in os.listdir():
    img2.append(cv2.imread(r"C:\Users\SSS\Desktop\opencv_task\2\{}".format(i),0).flatten())
    data_two=pd.DataFrame({'array':img2,'label':2})
img2
# Out:
# [array([199, 199, 196, ...,   1,   0,   0], dtype=uint8),
#  array([199, 199, 196, ...,   1,   0,   0], dtype=uint8),
#  array([195, 195, 194, ...,   0,   0,   0], dtype=uint8),
#  array([195, 195, 194, ...,   0,   0,   0], dtype=uint8),
#  array([195, 195, 194, ...,   0,   0,   0], dtype=uint8),
#  array([197, 196, 195, ...,   0,   0,   0], dtype=uint8),
#  array([197, 196, 195, ...,   0,   0,   0], dtype=uint8),
#  array([197, 196, 195, ...,   0,   0,   0], dtype=uint8),
#  array([194, 193, 192, ...,   0,   0,   0], dtype=uint8),
#  array([194, 193, 192, ...,   0,   0,   0], dtype=uint8),
#  array([194, 193, 192, ...,   0,   0,   0], dtype=uint8),
#  array([199, 198, 196, ...,   0,   0,   0], dtype=uint8),
#  array([199, 198, 196, ...,   0,   0,   0], dtype=uint8),
#  array([199, 198, 196, ...,   0,   0,   0], dtype=uint8),
#  array([200, 199, 197, ...,   0,   0,   0], dtype=uint8),
#  array([200, 199, 197, ...,   0,   0,   0], dtype=uint8),
# ...

# %%
data_two
# Out:
#                                                 array  label
# 0   [199, 199, 196, 194, 193, 192, 191, 190, 188, ...      2
# 1   [199, 199, 196, 194, 193, 192, 191, 190, 188, ...      2
# 2   [195, 195, 194, 192, 190, 189, 189, 189, 187, ...      2
# 3   [195, 195, 194, 192, 190, 189, 189, 189, 187, ...      2
# 4   [195, 195, 194, 192, 190, 189, 189, 189, 187, ...      2
# ..                                                ...    ...
# 77  [200, 199, 198, 197, 195, 194, 193, 191, 191, ...      2
# 78  [199, 199, 199, 198, 197, 196, 194, 193, 193, ...      2
# 79  [199, 199, 199, 198, 197, 196, 194, 193, 193, ...      2
# 80  [199, 199, 199, 198, 197, 196, 194, 193, 193, ...      2
# 81  [198, 199, 198, 197, 196, 195, 193, 191, 192, ...      2
#
# [82 rows x 2 columns]

# %%
os.chdir(r"C:\Users\SSS\Desktop\opencv_task\3")
img3=[]
for i in os.listdir():
    img3.append(cv2.imread(r"C:\Users\SSS\Desktop\opencv_task\3\{}".format(i),0).flatten())
    data_three=pd.DataFrame({'array':img3,'label':3})
img3
# Out:
# [array([199, 199, 198, ...,   1,   0,   0], dtype=uint8),
#  array([199, 199, 198, ...,   1,   0,   0], dtype=uint8),
#  array([200, 199, 197, ...,   0,   0,   0], dtype=uint8),
#  array([200, 199, 197, ...,   0,   0,   0], dtype=uint8),
#  array([200, 199, 197, ...,   0,   0,   0], dtype=uint8),
#  array([198, 198, 198, ...,   0,   0,   0], dtype=uint8),
#  array([198, 198, 198, ...,   0,   0,   0], dtype=uint8),
#  array([198, 198, 198, ...,   0,   0,   0], dtype=uint8),
#  array([198, 197, 196, ...,   0,   0,   0], dtype=uint8),
#  array([198, 197, 196, ...,   0,   0,   0], dtype=uint8),
#  array([198, 197, 196, ...,   0,   0,   0], dtype=uint8),
#  array([195, 195, 194, ...,   0,   0,   0], dtype=uint8),
#  array([195, 195, 194, ...,   0,   0,   0], dtype=uint8),
#  array([195, 195, 194, ...,   0,   0,   0], dtype=uint8),
#  array([198, 198, 197, ...,   0,   0,   0], dtype=uint8),
#  array([198, 198, 197, ...,   0,   0,   0], dtype=uint8),
# ...

# %%
data_three
# Out:
#                                                 array  label
# 0   [199, 199, 198, 197, 196, 194, 192, 191, 192, ...      3
# 1   [199, 199, 198, 197, 196, 194, 192, 191, 192, ...      3
# 2   [200, 199, 197, 196, 195, 194, 192, 190, 188, ...      3
# 3   [200, 199, 197, 196, 195, 194, 192, 190, 188, ...      3
# 4   [200, 199, 197, 196, 195, 194, 192, 190, 188, ...      3
# 5   [198, 198, 198, 196, 193, 190, 189, 188, 187, ...      3
# 6   [198, 198, 198, 196, 193, 190, 189, 188, 187, ...      3
# 7   [198, 198, 198, 196, 193, 190, 189, 188, 187, ...      3
# 8   [198, 197, 196, 195, 193, 192, 192, 192, 188, ...      3
# 9   [198, 197, 196, 195, 193, 192, 192, 192, 188, ...      3
# 10  [198, 197, 196, 195, 193, 192, 192, 192, 188, ...      3
# 11  [195, 195, 194, 193, 192, 191, 189, 187, 185, ...      3
# 12  [195, 195, 194, 193, 192, 191, 189, 187, 185, ...      3
# 13  [195, 195, 194, 193, 192, 191, 189, 187, 185, ...      3
# ...

# %%
os.chdir(r"C:\Users\SSS\Desktop\opencv_task\4")
img4=[]
for i in os.listdir():
    img4.append(cv2.imread(r"C:\Users\SSS\Desktop\opencv_task\4\{}".format(i),0).flatten())
    data_four=pd.DataFrame({'array':img4,'label':4})
img4
# Out:
# [array([196, 196, 195, ...,   0,   0,   0], dtype=uint8),
#  array([197, 196, 194, ...,   1,   1,   1], dtype=uint8),
#  array([197, 196, 194, ...,   1,   1,   1], dtype=uint8),
#  array([197, 196, 194, ...,   1,   1,   1], dtype=uint8),
#  array([193, 194, 194, ...,   0,   0,   0], dtype=uint8),
#  array([193, 194, 194, ...,   0,   0,   0], dtype=uint8),
#  array([193, 194, 194, ...,   0,   0,   0], dtype=uint8),
#  array([197, 197, 195, ...,   0,   0,   0], dtype=uint8),
#  array([197, 197, 195, ...,   0,   0,   0], dtype=uint8),
#  array([197, 197, 195, ...,   0,   0,   0], dtype=uint8),
#  array([197, 196, 194, ...,   2,   1,   1], dtype=uint8),
#  array([197, 196, 194, ...,   2,   1,   1], dtype=uint8),
#  array([197, 196, 194, ...,   2,   1,   1], dtype=uint8),
#  array([193, 193, 193, ...,   0,   0,   0], dtype=uint8),
#  array([193, 193, 193, ...,   0,   0,   0], dtype=uint8),
#  array([197, 196, 194, ...,   0,   0,   0], dtype=uint8),
# ...

# %%
data_four
# Out:
#                                                 array  label
# 0   [196, 196, 195, 194, 193, 191, 189, 186, 185, ...      4
# 1   [197, 196, 194, 193, 192, 191, 189, 188, 186, ...      4
# 2   [197, 196, 194, 193, 192, 191, 189, 188, 186, ...      4
# 3   [197, 196, 194, 193, 192, 191, 189, 188, 186, ...      4
# 4   [193, 194, 194, 193, 192, 190, 188, 186, 184, ...      4
# ..                                                ...    ...
# 93  [195, 195, 193, 192, 190, 190, 188, 187, 185, ...      4
# 94  [195, 195, 193, 192, 190, 190, 188, 187, 185, ...      4
# 95  [195, 195, 193, 192, 190, 190, 188, 187, 185, ...      4
# 96  [196, 196, 195, 194, 193, 191, 189, 186, 185, ...      4
# 97  [196, 196, 195, 194, 193, 191, 189, 186, 185, ...      4
#
# [98 rows x 2 columns]

# %%
os.chdir(r"C:\Users\SSS\Desktop\opencv_task\5")
img5=[]
for i in os.listdir():
    img5.append(cv2.imread(r"C:\Users\SSS\Desktop\opencv_task\5\{}".format(i),0).flatten())
    data_five=pd.DataFrame({'array':img5,'label':5})
img5
# Out:
# [array([157, 154, 151, ...,   0,   0,   0], dtype=uint8),
#  array([157, 154, 151, ...,   0,   0,   0], dtype=uint8),
#  array([159, 157, 153, ...,   0,   0,   0], dtype=uint8),
#  array([159, 157, 153, ...,   0,   0,   0], dtype=uint8),
#  array([159, 157, 153, ...,   0,   0,   0], dtype=uint8),
#  array([161, 160, 158, ...,   0,   0,   0], dtype=uint8),
#  array([161, 160, 158, ...,   0,   0,   0], dtype=uint8),
#  array([161, 160, 158, ...,   0,   0,   0], dtype=uint8),
#  array([162, 160, 158, ...,   0,   0,   0], dtype=uint8),
#  array([162, 160, 158, ...,   0,   0,   0], dtype=uint8),
#  array([163, 160, 159, ...,   0,   0,   0], dtype=uint8),
#  array([163, 160, 159, ...,   0,   0,   0], dtype=uint8),
#  array([163, 160, 159, ...,   0,   0,   0], dtype=uint8),
#  array([166, 168, 162, ...,   0,   0,   0], dtype=uint8),
#  array([166, 168, 162, ...,   0,   0,   0], dtype=uint8),
#  array([166, 168, 162, ...,   0,   0,   0], dtype=uint8),
# ...

# %%
data_five
# Out:
#                                                 array  label
# 0   [157, 154, 151, 150, 150, 149, 147, 146, 142, ...      5
# 1   [157, 154, 151, 150, 150, 149, 147, 146, 142, ...      5
# 2   [159, 157, 153, 151, 150, 148, 147, 145, 149, ...      5
# 3   [159, 157, 153, 151, 150, 148, 147, 145, 149, ...      5
# 4   [159, 157, 153, 151, 150, 148, 147, 145, 149, ...      5
# 5   [161, 160, 158, 156, 154, 152, 149, 146, 144, ...      5
# 6   [161, 160, 158, 156, 154, 152, 149, 146, 144, ...      5
# 7   [161, 160, 158, 156, 154, 152, 149, 146, 144, ...      5
# 8   [162, 160, 158, 157, 157, 156, 156, 156, 156, ...      5
# 9   [162, 160, 158, 157, 157, 156, 156, 156, 156, ...      5
# 10  [163, 160, 159, 159, 158, 156, 155, 156, 150, ...      5
# 11  [163, 160, 159, 159, 158, 156, 155, 156, 150, ...      5
# 12  [163, 160, 159, 159, 158, 156, 155, 156, 150, ...      5
# 13  [166, 168, 162, 164, 160, 159, 156, 154, 152, ...      5
# ...

# %% [markdown]
# created array and label for one finger sign,two finger sign,three finger sign,four finger sign,five finger sign with label 1,2,3,4,5 for grey scale image converted to vector
