# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\SSS\Downloads\data_science_job.csv")
data.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# ...

# %%
d=data.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  18679 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  float64
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  training_hours          18392 non-null  float64
#  12  target                  19158 non-null  float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1.9+ MB

# %%
data.isnull().mean()*100   # mean-avearge null value # if column have more null dont remove
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
data1=data.isnull().mean()*100

# %%
data1<5
# Out:
# enrollee_id                True
# city                       True
# city_development_index     True
# gender                    False
# relevent_experience        True
# enrolled_university        True
# education_level            True
# major_discipline          False
# experience                 True
# company_size              False
# company_type              False
# training_hours             True
# target                     True
# dtype: bool

# %%
data1[data1<5]
# Out:
# enrollee_id               0.000000
# city                      0.000000
# city_development_index    2.500261
# relevent_experience       0.000000
# enrolled_university       2.014824
# education_level           2.401086
# experience                0.339284
# training_hours            3.998330
# target                    0.000000
# dtype: float64

# %%
data1[(data1>0) & (data1<5)].index
# Out:
# Index(['city_development_index', 'enrolled_university', 'education_level',
#        'experience', 'training_hours'],
#       dtype='object')

# %%
data_new=d[data1[(data1>0) & (data1<5)].index].dropna()

# %%
data.shape
# Out:
# (19158, 13)

# %%
data_new.shape
# Out:
# (17182, 5)

# %%
data_new.head()
# Out:
#    city_development_index enrolled_university education_level  experience  \
# 0                   0.920       no_enrollment        Graduate        20.0
# 1                   0.776       no_enrollment        Graduate        15.0
# 2                   0.624    Full time course        Graduate         5.0
# 4                   0.767       no_enrollment         Masters        20.0
# 5                   0.764    Part time course        Graduate        11.0
#
#    training_hours
# 0            36.0
# 1            47.0
# 2            83.0
# 4             8.0
# 5            24.0

# %%
sns.distplot(data_new["city_development_index"],label="after")
sns.distplot(d["city_development_index"],label="before")
plt.legend()
# Out:
# C:\Users\SSS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SSS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# if we remove null value in city_development_index,not difference that much in difference in distribution,so we can remove null

# %%
sns.distplot(data_new["experience"],label="after")
sns.distplot(d["experience"],label="before")
plt.legend()
# Out:
# C:\Users\SSS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SSS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data_new["training_hours"],label="after")
sns.distplot(d["training_hours"],label="before")
plt.legend()
# Out:
# C:\Users\SSS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SSS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# perform ratio for categorical column and check whether remove null and before

# %%
d["enrolled_university"].value_counts()/d.shape[0]
# Out:
# no_enrollment       0.721213
# Full time course    0.196106
# Part time course    0.062533
# Name: enrolled_university, dtype: float64

# %%
data_new["enrolled_university"].value_counts()/data_new.shape[0]
# Out:
# no_enrollment       0.735188
# Full time course    0.200733
# Part time course    0.064079
# Name: enrolled_university, dtype: float64

# %%
# no such difference in ratio

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().mean()*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
# if above 40% null drop column

# %%
df["age"].mean()
# Out:
# 29.69911764705882

# %%
df1=df["age"].fillna(df["age"].mean())

# %%
df1
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
sns.distplot(df["age"],label="before_im")
sns.distplot(df1,label="after_im")
plt.legend()
# Out:
# C:\Users\SSS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SSS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# dont impute

# %%
df["age"].median()
# Out:
# 28.0

# %%
df2=df["age"].fillna(df["age"].median())

# %%
sns.distplot(df["age"],label="before_im")
sns.distplot(df2,label="after_im")
plt.legend()
# Out:
# C:\Users\SSS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SSS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df["age"].var()
# Out:
# 211.0191247463081

# %%
df1=df["age"].fillna(df["age"].var())

# %%
from sklearn.impute import SimpleImputer  # numerical column can give n columns only do in this because default is mean

# %%
si=SimpleImputer(strategy="median")   # default-mean

# %%
si.fit_transform(df[["age"]])
# Out:
# array([[22.  ],
#        [38.  ],
#        [26.  ],
#        [35.  ],
#        [35.  ],
#        [28.  ],
#        [54.  ],
#        [ 2.  ],
#        [27.  ],
#        [14.  ],
#        [ 4.  ],
#        [58.  ],
#        [20.  ],
#        [39.  ],
#        [14.  ],
#        [55.  ],
#        [ 2.  ],
#        [28.  ],
#        [31.  ],
#        [28.  ],
#        [35.  ],
#        [34.  ],
#        [15.  ],
#        [28.  ],
#        [ 8.  ],
#        [38.  ],
#        [28.  ],
#        [19.  ],
#        [28.  ],
#        [28.  ],
#        [40.  ],
#        [28.  ],
#        [28.  ],
#        [66.  ],
#        [28.  ],
#        [42.  ],
#        [28.  ],
#        [21.  ],
#        [18.  ],
#        [14.  ],
#        [40.  ],
#        [27.  ],
#        [28.  ],
#        [ 3.  ],
#        [19.  ],
#        [28.  ],
#        [28.  ],
#        [28.  ],
#        [28.  ],
#        [18.  ],
#        [ 7.  ],
#        [21.  ],
#        [49.  ],
#        [29.  ],
#        [65.  ],
# ...

# %%
o=si.fit_transform(df[["age"]])

# %%
pd.DataFrame(o).isnull().sum()
# Out:
# 0    0
# dtype: int64

# %%
 # for categorical=most_frequent,constant=can give constant value 1
