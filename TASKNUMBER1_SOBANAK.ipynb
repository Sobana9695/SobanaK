# %% [markdown]
# # Option 1: Computer Vision
# Task1:
# Process any given image/pdf and read the text. Using open- CV approach and Py-tesseract only.
# User story:
# As a user I should be able to process images and extract the text from the image.

# %% [markdown]
# # Installing Libraries

# %%
pip install imutils
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25847 sha256=1563011ef694d71dc322c64fb40a0503ecc800c5def58359d11a015297b3b3a0
#   Stored in directory: c:\users\sss\appdata\local\pip\cache\wheels\4b\a5\2d\4a070a801d3a3d93f033d3ee9728f470f514826e89952df3ea
# Successfully built imutils
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-image
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import cv2
import pytesseract
import os
import traceback
import imutils
from imutils import contours
from imutils.perspective import four_point_transform
from skimage.filters import threshold_local

# %%
from PIL import Image

# %% [markdown]
# # OpenCV (Open source computer vision) is a library of programming functions mainly aimed at real-time computer vision.

# %%
os.chdir(r"C:\Users\SSS\Downloads\Data\Data\Task1")  # change the directory where task1 folder exists.

# %%
images=os.listdir()
images
# Out:
# ['1.jpg', '2.jpg', '3.jpg', '4.jpg', 'table.pdf']

# %%
img1=[]
for i in images[0:3]:
    img1.append(cv2.imread(r"C:\Users\SSS\Downloads\Data\Data\Task1\{}".format(i)))
img1
# Out:
# [array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
# ...

# %%
image = cv2.imread(r"C:\Users\SSS\Downloads\Data\Data\Task1\1.jpg")
image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %% [markdown]
# # Image is read using the imread function of opencv.

# %%
image = cv2.imread(r"C:\Users\SSS\Downloads\Data\Data\Task1\1.jpg")
# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)   # Convert the image to gray scale
gray = get_grayscale(image)
Image.fromarray(gray)
# Out:
# <PIL.Image.Image image mode=L size=1141x741>

# %% [markdown]
# # OpenCV in python helps to process an image and apply various functions like resizing image, pixel manipulations, object detection, etc.

# %%
import pytesseract as pt

# %% [markdown]
# # Python-tesseract is a wrapper for Google’s Tesseract-OCR Engine which is used to recognize text from images.

# %%
pt.pytesseract.tesseract_cmd=r"C:\Program Files\Tesseract-OCR\Tesseract.exe"

# %%
file=r"C:\Users\SSS\Downloads\Data\Data\Task1\1.jpg" 
image=Image.open(file)
text = pt.image_to_string(image)
print(text)   # we get text from image
# Out:
#
#
# ying an dependent contented he gentleman agreeable do be. Warrant
# emoved an in equally totally if. Del: Lor Sar
# objection do mr prevailed. Mr feeling do chiefly cordial in do. Hater timed folly
# right aware if oh truth. Imprudence attachment him his for sympathize. Large above
# be to means. Dashwood do provided stronger is. But discretion frequently sir the
# she instrument unaffected admiration everything.
#
#
#
#
#
#
#
#
#
#
#
# Her extensive perceived may any sincerity,
# see. Old propriety delighted
# Doubt meri
# northward. Congisted we atheruise arrang ng commanded d
# Cho old even song like tao yet been. ‘Literature inter doannouncing for
# terminated him inquietude day shy. Hi nm perhaps waiting if
# highest no it, Continued promotion has consulted fat improving not way.
#
# tramity. Indeed add rather may pretty
# i obj lion gam ten her.
# ntion smallness he
# ry it explained.
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
for i in range(1,4):
    file=r"C:\Users\SSS\Downloads\Data\Data\Task1\{}.jpg".format(i)
    image=Image.open(file)
    text = pt.image_to_string(image)
    print(text)
# Out:
#
#
# ying an dependent contented he gentleman agreeable do be. Warrant
# emoved an in equally totally if. Del: Lor Sar
# objection do mr prevailed. Mr feeling do chiefly cordial in do. Hater timed folly
# right aware if oh truth. Imprudence attachment him his for sympathize. Large above
# be to means. Dashwood do provided stronger is. But discretion frequently sir the
# she instrument unaffected admiration everything.
#
#
#
#
#
#
#
#
#
#
#
# Her extensive perceived may any sincerity,
# see. Old propriety delighted
# Doubt meri
# northward. Congisted we atheruise arrang ng commanded d
# Cho old even song like tao yet been. ‘Literature inter doannouncing for
# terminated him inquietude day shy. Hi nm perhaps waiting if
# highest no it, Continued promotion has consulted fat improving not way.
#
# tramity. Indeed add rather may pretty
# i obj lion gam ten her.
# ntion smallness he
# ry it explained.
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
